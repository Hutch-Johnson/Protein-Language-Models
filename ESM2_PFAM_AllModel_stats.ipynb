# %%
import os
import io
import gzip
import json
import warnings
import logging

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats

import matplotlib.patches as mpatches

from dotenv import load_dotenv
from google.cloud import storage

warnings.filterwarnings("ignore")
logging.getLogger("transformers").setLevel(logging.ERROR)

# %%
# load combined data

df = pd.read_csv("/Users/johnhutchens/Desktop/Practicum/Data/ESM2_ft_all_pfam_sp.csv.gz")

# %%
df.tail()
# Out:
#            model           domain_id uniprot_id in_pfam_train     n  rho_base  \
# 66289  all_pfams  P35712_PF00505_622     P35712           NaN  1251  0.231413
# 66290  all_pfams  P19878_PF00564_353     P19878           NaN  1213  0.469809
# 66291  all_pfams   P48431_PF00505_42     P48431           NaN  1232  0.266543
# 66292  all_pfams   Q06945_PF00505_60     Q06945           NaN  1207  0.326461
# 66293  all_pfams  P35711_PF00505_557     P35711           NaN  1158  0.260646
#
#              p_base    rho_ft          p_ft  delta_rho     pfam
# 66289  1.136879e-16  0.142435  4.222672e-07  -0.088978  PF00505
# 66290  1.280882e-67  0.376195  4.524484e-42  -0.093614  PF00564
# 66291  1.751323e-21  0.164364  6.521899e-09  -0.102179  PF00505
# 66292  2.272511e-31  0.223718  3.714482e-15  -0.102744  PF00505
# 66293  1.944839e-19  0.134941  4.063460e-06  -0.125704  PF00505

# %% [markdown]
# # All trained model

# %%
df_all = df[df['model']=='all_pfams']

# %%
df_all.head()
# Out:
#            model           domain_id uniprot_id in_pfam_train     n  rho_base  \
# 65772  all_pfams  Q9Y6N9_PF00595_207     Q9Y6N9           NaN  1255  0.378841
# 65773  all_pfams  P20936_PF00018_281     P20936           NaN  1158  0.422455
# 65774  all_pfams  Q86VP1_PF18112_729     Q86VP1           NaN   494  0.299746
# 65775  all_pfams  P22681_PF00627_854     P22681           NaN   850  0.235321
# 65776  all_pfams   Q9P0J7_PF05605_76     Q9P0J7           NaN  1093  0.303563
#
#              p_base    rho_ft           p_ft  delta_rho     pfam
# 65772  4.165029e-44  0.626113  1.456364e-137   0.247273  PF00595
# 65773  2.486852e-51  0.666934  6.875281e-150   0.244478  PF00018
# 65774  1.029321e-11  0.531721   2.119634e-37   0.231975  PF18112
# 65775  3.693812e-12  0.457588   3.250431e-45   0.222268  PF00627
# 65776  9.848891e-25  0.520061   9.076428e-77   0.216498  PF05605

# %% [markdown]
# ## Is delta_rho normaly distributed over all data?

# %%
df_all['delta_rho'].hist(bins=30)
plt.show()

# %%
stats.probplot(df['delta_rho'].dropna(), dist='norm', plot=plt)
plt.show()

# %% [markdown]
# ### Data is not normally distributed over the entire dataset.
# ### Use Wilcoxon.

# %%
w_all_all, p_all_all = stats.wilcoxon(df_all['rho_ft'], df_all['rho_base'], alternative='greater')
print(len(df_all['rho_ft']))
print(w_all_all)
print(p_all_all)
# Out:
# 522
# 109217.0
# 7.364445863416151e-33

# %%
print(f"Median improvement {df_all['delta_rho'].median()}")
print(f"Median improvement {df_all['delta_rho'].mean()}")
(df_all['delta_rho'] > 0).mean()
improved = df_all[df_all['delta_rho'] > 0]['delta_rho']
len(improved)
# Out:
# Median improvement 0.03117845077835085

# %% [markdown]
# # Checking all trained model on each PFAM

# %%
# counting domains in pfams

pfam_counts = (
    df[df['model']=='all_pfams']['pfam']
    .value_counts()
    .reset_index()
)

pfam_counts.columns = ['pfam', 'count']

# %%
pfam_counts.head(30)
# Out:
#         pfam  count
# 0    PF00046     37
# 1    PF00096     36
# 2    PF00018     36
# 3    PF00595     31
# 4    PF00397     26
# 5    PF00505     17
# 6    PF00249     15
# 7    PF02037     14
# 8    PF00157     12
# 9    PF01846     12
# 10   PF00030     12
# 11   PF00628     11
# 12   PF00105     10
# 13   PF00641     10
# 14   PF00313      9
# 15   PF00643      9
# 16   PF00013      9
# 17   PF00642      8
# 18   PF00412      8
# 19   PF06467      8
# 20   PF02376      8
# 21   PF14604      8
# 22   PF00627      7
# 23   PF02198      6
# 24   PF00226      6
# 25   PF13499      6
# 26   PF00536      6
# 27   PF07647      5
# 28   PF02209      4
# 29  rockdoms      3

# %%
pfam_valid = list(pfam_counts[pfam_counts['count'] > 4]['pfam'])

df_valid_all = df_all[df_all['pfam'].isin(pfam_valid)]

df_valid_all.head()
# Out:
#            model            domain_id uniprot_id in_pfam_train     n  \
# 65772  all_pfams   Q9Y6N9_PF00595_207     Q9Y6N9           NaN  1255
# 65773  all_pfams   P20936_PF00018_281     P20936           NaN  1158
# 65775  all_pfams   P22681_PF00627_854     P22681           NaN   850
# 65778  all_pfams  Q15911_PF00046_2147     Q15911           NaN  1055
# 65781  all_pfams   Q9UJ78_PF06467_334     Q9UJ78           NaN   678
#
#        rho_base        p_base    rho_ft           p_ft  delta_rho     pfam
# 65772  0.378841  4.165029e-44  0.626113  1.456364e-137   0.247273  PF00595
# 65773  0.422455  2.486852e-51  0.666934  6.875281e-150   0.244478  PF00018
# 65775  0.235321  3.693812e-12  0.457588   3.250431e-45   0.222268  PF00627
# 65778  0.320946  1.057353e-26  0.530777   1.004325e-77   0.209831  PF00046
# 65781  0.186344  1.029017e-06  0.376822   2.669503e-24   0.190478  PF06467

# %%
for pfam in pfam_valid:
    print("*"*100)
    print(pfam)
    df_pfam = df_valid_all[df_valid_all['pfam'] == pfam]
    w_pfam, p_pfam = stats.wilcoxon(df_pfam['rho_ft'], df_pfam['rho_base'], alternative='greater')
    print(len(df_pfam['rho_ft']))
    print(f"W-stat = {w_pfam}")
    print(f"p-value = {p_pfam}")
    print(f"Median improvement {df_pfam['delta_rho'].median()}")
    print(f"Median improvement {df_pfam['delta_rho'].mean()}")
    (df_pfam['delta_rho'] > 0).mean()
    improved = df_pfam[df_pfam['delta_rho'] > 0]['delta_rho']
    print(f"Number improved {len(improved)}")
    print("*"*100)
    print()
# Out:
# ****************************************************************************************************
# PF00046
# 37
# W-stat = 703.0
# p-value = 7.275957614183426e-12
# Median improvement 0.1219634762329135
# Median improvement 0.12635322659349685
# Number improved 37
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00096
# 36
# W-stat = 521.0
# p-value = 0.0012400038540363312
# Median improvement 0.016197284610799348
# Median improvement 0.02201160225810122
# Number improved 26
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00018
# 36
# W-stat = 396.0
# p-value = 0.16514642159745563
# Median improvement 0.02267064170107625
# Median improvement 0.015130325367505868
# Number improved 21
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00595
# 31
# W-stat = 452.0
# p-value = 6.7623332142829895e-06
# Median improvement 0.040634160543713
# Median improvement 0.052252601455270366
# Number improved 26
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00397
# 26
# W-stat = 104.0
# p-value = 0.9665583968162537
# Median improvement -0.02517105213936445
# Median improvement -0.012747326649343102
# Number improved 8
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00505
# 17
# W-stat = 41.0
# p-value = 0.9556732177734375
# Median improvement -0.0630064730553313
# Median improvement -0.03675604193228034
# Number improved 4
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00249
# 15
# W-stat = 113.0
# p-value = 0.000579833984375
# Median improvement 0.0650858837106999
# Median improvement 0.055077800111449055
# Number improved 12
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF02037
# 14
# W-stat = 71.0
# p-value = 0.1337890625
# Median improvement 0.024906259345368352
# Median improvement 0.028922180066039107
# Number improved 9
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00157
# 12
# W-stat = 59.0
# p-value = 0.064697265625
# Median improvement 0.0146317923914582
# Median improvement 0.02390080113002137
# Number improved 7
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF01846
# 12
# W-stat = 69.0
# p-value = 0.008056640625
# Median improvement 0.0400197406260822
# Median improvement 0.04005454799037693
# Number improved 9
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00030
# 12
# W-stat = 71.0
# p-value = 0.004638671875
# Median improvement 0.01729357275159055
# Median improvement 0.037133226963884845
# Number improved 11
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00628
# 11
# W-stat = 66.0
# p-value = 0.00048828125
# Median improvement 0.0230570257810583
# Median improvement 0.04403857425160397
# Number improved 11
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00105
# 10
# W-stat = 30.0
# p-value = 0.4228515625
# Median improvement 0.00027421881241790005
# Median improvement 0.0016895167598432307
# Number improved 5
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00641
# 10
# W-stat = 53.0
# p-value = 0.0029296875
# Median improvement 0.08501992480624081
# Median improvement 0.08097656187530387
# Number improved 9
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00313
# 9
# W-stat = 27.0
# p-value = 0.326171875
# Median improvement 0.0030639915628641
# Median improvement 0.0099288503606183
# Number improved 5
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00643
# 9
# W-stat = 45.0
# p-value = 0.001953125
# Median improvement 0.0670264059753545
# Median improvement 0.0664936314492367
# Number improved 9
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00013
# 9
# W-stat = 40.0
# p-value = 0.01953125
# Median improvement 0.0595159444563905
# Median improvement 0.06903029610586114
# Number improved 7
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00642
# 8
# W-stat = 33.0
# p-value = 0.01953125
# Median improvement 0.0561872829210855
# Median improvement 0.048909173631562344
# Number improved 7
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00412
# 8
# W-stat = 35.0
# p-value = 0.0078125
# Median improvement 0.09500856911179725
# Median improvement 0.09255672114806425
# Number improved 7
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF06467
# 8
# W-stat = 36.0
# p-value = 0.00390625
# Median improvement 0.07991752104444375
# Median improvement 0.10156206793247896
# Number improved 8
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF02376
# 8
# W-stat = 36.0
# p-value = 0.00390625
# Median improvement 0.08621706667432895
# Median improvement 0.08465921248355901
# Number improved 8
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF14604
# 8
# W-stat = 17.0
# p-value = 0.578125
# Median improvement -0.00254102976154095
# Median improvement 0.004528645709145014
# Number improved 3
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00627
# 7
# W-stat = 24.0
# p-value = 0.0546875
# Median improvement 0.0908872189823111
# Median improvement 0.07431387567601748
# Number improved 5
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF02198
# 6
# W-stat = 14.0
# p-value = 0.28125
# Median improvement 0.0142174467384145
# Median improvement 0.021257416242374445
# Number improved 3
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00226
# 6
# W-stat = 10.0
# p-value = 0.578125
# Median improvement -0.005863898311694
# Median improvement 0.0010088454920901338
# Number improved 2
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF13499
# 6
# W-stat = 21.0
# p-value = 0.015625
# Median improvement 0.028410135187109303
# Median improvement 0.047818441726444165
# Number improved 6
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00536
# 6
# W-stat = 21.0
# p-value = 0.015625
# Median improvement 0.08861066139450716
# Median improvement 0.09327593470500643
# Number improved 6
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF07647
# 5
# W-stat = 14.0
# p-value = 0.0625
# Median improvement 0.0347157726971191
# Median improvement 0.027819220705004817
# Number improved 4
# ****************************************************************************************************

# %%
results = []

for pfam in pfam_valid:
    df_pfam = df_valid_all[df_valid_all["pfam"] == pfam]

    # skip empty / too small groups (important for wilcoxon)
    if len(df_pfam) < 2:
        continue

    w_stat, p_val = stats.wilcoxon(
        df_pfam["rho_ft"],
        df_pfam["rho_base"],
        alternative="greater"
    )

    delta = df_pfam["delta_rho"]

    results.append({
        "all_pfam": pfam,
        "all_n": len(df_pfam),
        "all_wilcoxon_W": w_stat,
        "all_p_value": p_val,
        "all_median_delta_rho": delta.median(),
        "all_mean_delta_rho": delta.mean(),
        "all_frac_improved": (delta > 0).mean(),
        "all_n_improved": (delta > 0).sum(),
    })

all_pfam_results_df = pd.DataFrame(results)

# %%
all_pfam_results_df
# Out:
#    all_pfam  all_n  all_wilcoxon_W   all_p_value  all_median_delta_rho  \
# 0   PF00046     37           703.0  7.275958e-12              0.121963
# 1   PF00096     36           521.0  1.240004e-03              0.016197
# 2   PF00018     36           396.0  1.651464e-01              0.022671
# 3   PF00595     31           452.0  6.762333e-06              0.040634
# 4   PF00397     26           104.0  9.665584e-01             -0.025171
# 5   PF00505     17            41.0  9.556732e-01             -0.063006
# 6   PF00249     15           113.0  5.798340e-04              0.065086
# 7   PF02037     14            71.0  1.337891e-01              0.024906
# 8   PF00157     12            59.0  6.469727e-02              0.014632
# 9   PF01846     12            69.0  8.056641e-03              0.040020
# 10  PF00030     12            71.0  4.638672e-03              0.017294
# 11  PF00628     11            66.0  4.882812e-04              0.023057
# 12  PF00105     10            30.0  4.228516e-01              0.000274
# 13  PF00641     10            53.0  2.929688e-03              0.085020
# 14  PF00313      9            27.0  3.261719e-01              0.003064
# 15  PF00643      9            45.0  1.953125e-03              0.067026
# 16  PF00013      9            40.0  1.953125e-02              0.059516
# 17  PF00642      8            33.0  1.953125e-02              0.056187
# 18  PF00412      8            35.0  7.812500e-03              0.095009
# 19  PF06467      8            36.0  3.906250e-03              0.079918
# 20  PF02376      8            36.0  3.906250e-03              0.086217
# 21  PF14604      8            17.0  5.781250e-01             -0.002541
# 22  PF00627      7            24.0  5.468750e-02              0.090887
# 23  PF02198      6            14.0  2.812500e-01              0.014217
# 24  PF00226      6            10.0  5.781250e-01             -0.005864
# 25  PF13499      6            21.0  1.562500e-02              0.028410
# 26  PF00536      6            21.0  1.562500e-02              0.088611
# 27  PF07647      5            14.0  6.250000e-02              0.034716
#
#     all_mean_delta_rho  all_frac_improved  all_n_improved
# 0             0.126353           1.000000              37
# 1             0.022012           0.722222              26
# 2             0.015130           0.583333              21
# 3             0.052253           0.838710              26
# 4            -0.012747           0.307692               8
# 5            -0.036756           0.235294               4
# 6             0.055078           0.800000              12
# 7             0.028922           0.642857               9
# 8             0.023901           0.583333               7
# 9             0.040055           0.750000               9
# 10            0.037133           0.916667              11
# 11            0.044039           1.000000              11
# 12            0.001690           0.500000               5
# 13            0.080977           0.900000               9
# 14            0.009929           0.555556               5
# 15            0.066494           1.000000               9
# 16            0.069030           0.777778               7
# 17            0.048909           0.875000               7
# 18            0.092557           0.875000               7
# 19            0.101562           1.000000               8
# 20            0.084659           1.000000               8
# 21            0.004529           0.375000               3
# 22            0.074314           0.714286               5
# 23            0.021257           0.500000               3
# 24            0.001009           0.333333               2
# 25            0.047818           1.000000               6
# 26            0.093276           1.000000               6
# 27            0.027819           0.800000               4

# %% [markdown]
# # PFAM trained models

# %%
# counting domains in pfams

pfam_counts = (
    df[df['model']=='all_pfams']['pfam']
    .value_counts()
    .reset_index()
)

pfam_counts.columns = ['pfam', 'count']

# %%
pfam_counts.head(30)

# %%
model_valid = list(pfam_counts[pfam_counts['count'] > 4]['pfam'])

df_valid = df[df['model'].isin(model_valid)]

df_valid.head()
# Out:
#       model           domain_id uniprot_id in_pfam_train     n  rho_base  \
# 8   PF06467  Q9UJ78_PF06467_334     Q9UJ78          True   678  0.186368
# 23  PF00013  Q9Y6N9_PF00595_207     Q9Y6N9         False  1255  0.378841
# 24  PF00412  Q9Y6N9_PF00595_207     Q9Y6N9         False  1255  0.378841
# 26  PF00013  Q15365_PF00013_278     Q15365          True  1360  0.370119
# 32  PF00536  Q8WU90_PF18044_104     Q8WU90         False   397  0.166906
#
#           p_base    rho_ft           p_ft  delta_rho     pfam
# 8   1.025662e-06  0.587158   4.585924e-64   0.400790  PF06467
# 23  4.165029e-44  0.706444  2.614294e-190   0.327603  PF00595
# 24  4.165029e-44  0.706201  4.019696e-190   0.327360  PF00595
# 26  2.091066e-45  0.695142  6.704938e-197   0.325022  PF00013
# 32  8.422100e-04  0.476838   6.240748e-24   0.309932  PF18044

# %% [markdown]
# ## Are any delta_rho's normally distributed over entire dataset?

# %%
models = df_valid["model"].unique()

ncols = 4
nrows = int(np.ceil(len(models) / ncols))

fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(4*ncols, 3*nrows)
)

axes = np.array(axes).flatten()

for ax, model in zip(axes, models):
    df_valid.loc[df_valid["model"] == model, "delta_rho"].hist(
        bins=30,
        ax=ax
    )
    ax.set_title(model)
    ax.set_xlabel("delta_rho")

# hide unused axes
for ax in axes[len(models):]:
    ax.set_visible(False)

plt.tight_layout()
plt.show()

# %%
models = df_valid["model"].unique()

ncols = 4
nrows = int(np.ceil(len(models) / ncols))

fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(4*ncols, 3*nrows)
)

axes = np.array(axes).flatten()

for ax, model in zip(axes, models):
    stats.probplot(
        df_valid.loc[df_valid["model"] == model, "delta_rho"].dropna(),
        dist='norm',
        plot=ax
    )
    ax.set_title(model)
    ax.set_xlabel("delta_rho")

# hide unused axes
for ax in axes[len(models):]:
    ax.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Some PFAM models looks almost normal.  Most do not.
# ## We use Wilcoxon for every model.

# %%
models = df_valid["model"].unique()

for model in models:
    print("*"*100)
    print(model)
    df_pfam = df_valid[df_valid['model'] == model]
    w_pfam, p_pfam = stats.wilcoxon(df_pfam['rho_ft'], df_pfam['rho_base'], alternative='greater')
    print(len(df_pfam['rho_ft']))
    print(f"W-stat = {w_pfam}")
    print(f"p-value = {p_pfam}")
    print(f"Median improvement {df_pfam['delta_rho'].median()}")
    print(f"Median improvement {df_pfam['delta_rho'].mean()}")
    (df_pfam['delta_rho'] > 0).mean()
    improved = df_pfam[df_pfam['delta_rho'] > 0]['delta_rho']
    print(f"Number improved {len(improved)}")
    print("*"*100)
    print()
# Out:
# ****************************************************************************************************
# PF06467
# 522
# W-stat = 91667.0
# p-value = 5.549212935331964e-12
# Median improvement 0.0114268119673266
# Median improvement 0.017109826324015153
# Number improved 321
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00013
# 522
# W-stat = 121883.0
# p-value = 7.311354654231139e-55
# Median improvement 0.033005042055102046
# Median improvement 0.0462117322046613
# Number improved 415
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00412
# 522
# W-stat = 132393.0
# p-value = 1.4979915720458492e-77
# Median improvement 0.050859388271172604
# Median improvement 0.06622340635275807
# Number improved 477
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00536
# 522
# W-stat = 69536.0
# p-value = 0.3547382085496241
# Median improvement 0.0043435909190396495
# Median improvement -0.011609552194961301
# Number improved 270
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00096
# 522
# W-stat = 80496.0
# p-value = 0.00019157683708147482
# Median improvement 0.0024168701093881502
# Median improvement 0.008950459205481733
# Number improved 277
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00642
# 522
# W-stat = 120676.0
# p-value = 1.6300685602398531e-52
# Median improvement 0.0184247434931471
# Median improvement 0.027919692560147466
# Number improved 410
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF02037
# 522
# W-stat = 114451.0
# p-value = 3.0308856119684475e-41
# Median improvement 0.0357982259922353
# Median improvement 0.045569928036983835
# Number improved 398
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00595
# 522
# W-stat = 122177.0
# p-value = 1.9230695279944784e-55
# Median improvement 0.02476281108015345
# Median improvement 0.03655657430985146
# Number improved 424
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00249
# 522
# W-stat = 133107.0
# p-value = 3.0777222611161014e-79
# Median improvement 0.03115262654078975
# Median improvement 0.03919449693252281
# Number improved 474
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF07647
# 522
# W-stat = 132484.0
# p-value = 9.151591025814272e-78
# Median improvement 0.0332901200712834
# Median improvement 0.040981530340574855
# Number improved 478
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00627
# 522
# W-stat = 120881.0
# p-value = 6.563219213397012e-53
# Median improvement 0.0135437979606375
# Median improvement 0.018574966020709377
# Number improved 423
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF01846
# 522
# W-stat = 104116.0
# p-value = 1.2110765465316918e-25
# Median improvement 0.00741810859379965
# Median improvement 0.00886983863787644
# Number improved 372
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF02376
# 522
# W-stat = 120859.0
# p-value = 7.237522668273297e-53
# Median improvement 0.03029767328432815
# Median improvement 0.03827342781008493
# Number improved 416
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00505
# 522
# W-stat = 33519.0
# p-value = 1.0
# Median improvement -0.02492303439211565
# Median improvement -0.03264547925607509
# Number improved 148
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00046
# 522
# W-stat = 7247.0
# p-value = 1.0
# Median improvement -0.0997326595656205
# Median improvement -0.09684701684347316
# Number improved 53
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00643
# 522
# W-stat = 109037.0
# p-value = 1.3735185858570855e-32
# Median improvement 0.0096000910705271
# Median improvement 0.019058325225641454
# Number improved 363
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF02198
# 522
# W-stat = 90747.0
# p-value = 3.40808938934063e-11
# Median improvement 0.0030447046096950996
# Median improvement 0.006973233413707806
# Number improved 306
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00226
# 522
# W-stat = 15845.0
# p-value = 1.0
# Median improvement -0.01025245214709355
# Median improvement -0.010380700827536902
# Number improved 99
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00641
# 522
# W-stat = 81532.0
# p-value = 5.860073607974635e-05
# Median improvement 0.00103022159920375
# Median improvement 0.004459956281988837
# Number improved 281
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00030
# 522
# W-stat = 86476.0
# p-value = 6.255217229946595e-08
# Median improvement 0.002298927489903
# Median improvement 0.005835095223646895
# Number improved 297
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00157
# 522
# W-stat = 76078.0
# p-value = 0.011603297692639321
# Median improvement 0.00174108761727545
# Median improvement 0.0027126105228800546
# Number improved 287
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF13499
# 522
# W-stat = 112231.0
# p-value = 1.4447799534982047e-37
# Median improvement 0.0028488309601729
# Median improvement 0.004354037019245433
# Number improved 382
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00628
# 522
# W-stat = 66491.0
# p-value = 0.695191246958707
# Median improvement -0.0005583472537993
# Median improvement 0.0010372522114712648
# Number improved 250
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00105
# 522
# W-stat = 118023.0
# p-value = 1.5393208356651903e-47
# Median improvement 0.0066045265088990005
# Median improvement 0.008435833117983668
# Number improved 406
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF14604
# 522
# W-stat = 58315.0
# p-value = 0.9980242363846663
# Median improvement -0.00016294382268725
# Median improvement -6.691734244642583e-05
# Number improved 218
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00018
# 522
# W-stat = 58811.0
# p-value = 0.9969106548403996
# Median improvement -0.0001759656689311
# Median improvement -7.454806779415465e-05
# Number improved 232
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00397
# 522
# W-stat = 91253.0
# p-value = 1.2667986226842058e-11
# Median improvement 5.9699993496656334e-05
# Median improvement 0.00011637423144201428
# Number improved 303
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00313
# 522
# W-stat = 30730.0
# p-value = 1.0
# Median improvement -7.810371024950802e-05
# Median improvement -7.330070772954498e-05
# Number improved 149
# ****************************************************************************************************

# %%
results = []

models = df_valid["model"].unique()

for model in models:
    df_model = df_valid[df_valid["model"] == model]

    w_stat, p_val = stats.wilcoxon(
        df_model["rho_ft"],
        df_model["rho_base"],
        alternative="greater"
    )

    delta = df_model["delta_rho"]

    results.append({
        "model": model,
        "n": len(df_model),
        "wilcoxon_W": w_stat,
        "p_value": p_val,
        "median_delta_rho": delta.median(),
        "mean_delta_rho": delta.mean(),
        "frac_improved": (delta > 0).mean(),
        "n_improved": (delta > 0).sum(),
    })

results_df = pd.DataFrame(results)

# %%
results_df.head()
# Out:
#      model    n  wilcoxon_W       p_value  median_delta_rho  mean_delta_rho  \
# 0  PF06467  522     91667.0  5.549213e-12          0.011427        0.017110
# 1  PF00013  522    121883.0  7.311355e-55          0.033005        0.046212
# 2  PF00412  522    132393.0  1.497992e-77          0.050859        0.066223
# 3  PF00536  522     69536.0  3.547382e-01          0.004344       -0.011610
# 4  PF00096  522     80496.0  1.915768e-04          0.002417        0.008950
#
#    frac_improved  n_improved
# 0       0.614943         321
# 1       0.795019         415
# 2       0.913793         477
# 3       0.517241         270
# 4       0.530651         277

# %% [markdown]
# ## Are any PFAM models normally distributed over their own PFAM?

# %%
df_valid_same = df_valid[df_valid["model"] == df_valid["pfam"]]

# %%
df_valid_same[df_valid_same["model"]=="PF00046"].shape
# Out:
# (37, 11)

# %%
models = df_valid_same["model"].unique()

ncols = 4
nrows = int(np.ceil(len(models) / ncols))

fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(4*ncols, 3*nrows)
)

axes = np.array(axes).flatten()

for ax, model in zip(axes, models):
    df_valid_same.loc[df_valid_same["model"] == model, "delta_rho"].hist(
        bins=30,
        ax=ax
    )
    ax.set_title(model)
    ax.set_xlabel("delta_rho")

# hide unused axes
for ax in axes[len(models):]:
    ax.set_visible(False)

plt.tight_layout()
plt.show()

# %%
models = df_valid_same["model"].unique()

ncols = 4
nrows = int(np.ceil(len(models) / ncols))

fig, axes = plt.subplots(
    nrows=nrows,
    ncols=ncols,
    figsize=(4*ncols, 3*nrows)
)

axes = np.array(axes).flatten()

for ax, model in zip(axes, models):
    stats.probplot(
        df_valid_same.loc[df_valid_same["model"] == model, "delta_rho"].dropna(),
        dist='norm',
        plot=ax
    )
    ax.set_title(model)
    ax.set_xlabel("delta_rho")

# hide unused axes
for ax in axes[len(models):]:
    ax.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Wilcoxon tests for each PFAM model on its own PFAM

# %%
models = df_valid_same["model"].unique()

for model in models:
    print("*"*100)
    print(model)
    df_pfam = df_valid_same[df_valid_same['model'] == model]
    w_pfam, p_pfam = stats.wilcoxon(df_pfam['rho_ft'], df_pfam['rho_base'], alternative='greater')
    print(len(df_pfam['rho_ft']))
    print(f"W-stat = {w_pfam}")
    print(f"p-value = {p_pfam}")
    print(f"Median improvement {df_pfam['delta_rho'].median()}")
    print(f"Median improvement {df_pfam['delta_rho'].mean()}")
    (df_pfam['delta_rho'] > 0).mean()
    improved = df_pfam[df_pfam['delta_rho'] > 0]['delta_rho']
    print(f"Number improved {len(improved)}")
    print("*"*100)
    print()
# Out:
# ****************************************************************************************************
# PF06467
# 8
# W-stat = 35.0
# p-value = 0.0078125
# Median improvement 0.12790927082304399
# Median improvement 0.15471431220255732
# Number improved 7
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00013
# 9
# W-stat = 45.0
# p-value = 0.001953125
# Median improvement 0.1595709977654201
# Median improvement 0.1374926781597151
# Number improved 9
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00595
# 31
# W-stat = 351.0
# p-value = 0.02172682899981737
# Median improvement 0.0143841672221062
# Median improvement 0.031645860395197734
# Number improved 19
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00249
# 15
# W-stat = 117.0
# p-value = 0.000152587890625
# Median improvement 0.0754745159337029
# Median improvement 0.08363868961465241
# Number improved 13
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00627
# 7
# W-stat = 25.0
# p-value = 0.0390625
# Median improvement 0.0599786261162115
# Median improvement 0.08404447733184538
# Number improved 6
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF01846
# 12
# W-stat = 53.0
# p-value = 0.150634765625
# Median improvement 0.0192263239090174
# Median improvement 0.04360333670573826
# Number improved 6
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00412
# 8
# W-stat = 36.0
# p-value = 0.00390625
# Median improvement 0.0852700576474663
# Median improvement 0.10800750830397432
# Number improved 8
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00505
# 17
# W-stat = 140.0
# p-value = 0.00067138671875
# Median improvement 0.0815160605461555
# Median improvement 0.09153463981320872
# Number improved 15
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF07647
# 5
# W-stat = 14.0
# p-value = 0.0625
# Median improvement 0.0935615069336589
# Median improvement 0.09011646446992251
# Number improved 4
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00642
# 8
# W-stat = 36.0
# p-value = 0.00390625
# Median improvement 0.12371593023995554
# Median improvement 0.12970072228126145
# Number improved 8
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00643
# 9
# W-stat = 45.0
# p-value = 0.001953125
# Median improvement 0.0691055807258754
# Median improvement 0.0852187924740402
# Number improved 9
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00096
# 36
# W-stat = 66.0
# p-value = 0.9999975565297063
# Median improvement -0.10936981699386569
# Median improvement -0.10176031506216658
# Number improved 5
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF02037
# 14
# W-stat = 24.0
# p-value = 0.9661865234375
# Median improvement -0.05934011074226
# Median improvement -0.05176682442316998
# Number improved 4
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF02198
# 6
# W-stat = 19.0
# p-value = 0.046875
# Median improvement 0.05112142303056255
# Median improvement 0.05465122108421164
# Number improved 5
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00046
# 37
# W-stat = 74.0
# p-value = 0.9999972268633428
# Median improvement -0.0912640951906364
# Median improvement -0.08976642082334212
# Number improved 4
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00226
# 6
# W-stat = 20.0
# p-value = 0.03125
# Median improvement 0.0649378480598634
# Median improvement 0.06245424976542438
# Number improved 5
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF02376
# 8
# W-stat = 28.0
# p-value = 0.09765625
# Median improvement 0.01821042415847465
# Median improvement 0.03259673063558025
# Number improved 5
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00641
# 10
# W-stat = 54.0
# p-value = 0.001953125
# Median improvement 0.069001742490442
# Median improvement 0.06277397493620644
# Number improved 9
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00030
# 12
# W-stat = 18.0
# p-value = 0.953857421875
# Median improvement -0.0525810745369045
# Median improvement -0.03833375544908692
# Number improved 3
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF13499
# 6
# W-stat = 21.0
# p-value = 0.015625
# Median improvement 0.04597912567521085
# Median improvement 0.04714469648015545
# Number improved 6
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00628
# 11
# W-stat = 50.0
# p-value = 0.07373046875
# Median improvement 0.0404655333925398
# Median improvement 0.025615689609480644
# Number improved 7
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00105
# 10
# W-stat = 52.0
# p-value = 0.0048828125
# Median improvement 0.046142039895284453
# Median improvement 0.038451038357513
# Number improved 9
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00157
# 12
# W-stat = 73.0
# p-value = 0.00244140625
# Median improvement 0.026052200993120403
# Median improvement 0.02712336852282977
# Number improved 11
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF14604
# 8
# W-stat = 32.0
# p-value = 0.02734375
# Median improvement 0.00270409700094625
# Median improvement 0.0037299446797555875
# Number improved 7
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00018
# 36
# W-stat = 590.0
# p-value = 7.304828613996506e-06
# Median improvement 0.0018553842515754
# Median improvement 0.0024173668527366944
# Number improved 29
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00397
# 26
# W-stat = 179.0
# p-value = 0.47014980018138885
# Median improvement -8.695235867494119e-05
# Median improvement 7.399896074666146e-05
# Number improved 11
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00313
# 9
# W-stat = 6.0
# p-value = 0.98046875
# Median improvement -0.00017728340892
# Median improvement -0.00032991409339437307
# Number improved 1
# ****************************************************************************************************
#
# ****************************************************************************************************
# PF00536
# 6
# W-stat = 0.0
# p-value = 1.0
# Median improvement -0.4205126382933405
# Median improvement -0.34925282526359075
# Number improved 0
# ****************************************************************************************************

# %%
results = []

models = df_valid_same["model"].unique()

for model in models:
    df_model = df_valid_same[df_valid_same["model"] == model]

    w_stat, p_val = stats.wilcoxon(
        df_model["rho_ft"],
        df_model["rho_base"],
        alternative="greater"
    )

    delta = df_model["delta_rho"]

    results.append({
        "model": model,
        "n": len(df_model),
        "pfam_wilcoxon_W": w_stat,
        "pfam_p_value": p_val,
        "pfam_median_delta_rho": delta.median(),
        "pfam_mean_delta_rho": delta.mean(),
        "pfam_frac_improved": (delta > 0).mean(),
        "pfam_n_improved": (delta > 0).sum(),
    })

PFAM_results_df = pd.DataFrame(results)

# %%
PFAM_results_df.head()
# Out:
#      model   n  pfam_wilcoxon_W  pfam_p_value  pfam_median_delta_rho  \
# 0  PF06467   8             35.0      0.007812               0.127909
# 1  PF00013   9             45.0      0.001953               0.159571
# 2  PF00595  31            351.0      0.021727               0.014384
# 3  PF00249  15            117.0      0.000153               0.075475
# 4  PF00627   7             25.0      0.039062               0.059979
#
#    pfam_mean_delta_rho  pfam_frac_improved  pfam_n_improved
# 0             0.154714            0.875000                7
# 1             0.137493            1.000000                9
# 2             0.031646            0.612903               19
# 3             0.083639            0.866667               13
# 4             0.084044            0.857143                6

# %%
all_pfam_results_df.head()
# Out:
#   all_pfam  all_n  all_wilcoxon_W   all_p_value  all_median_delta_rho  \
# 0  PF00046     37           703.0  7.275958e-12              0.121963
# 1  PF00096     36           521.0  1.240004e-03              0.016197
# 2  PF00018     36           396.0  1.651464e-01              0.022671
# 3  PF00595     31           452.0  6.762333e-06              0.040634
# 4  PF00397     26           104.0  9.665584e-01             -0.025171
#
#    all_mean_delta_rho  all_frac_improved  all_n_improved
# 0            0.126353           1.000000              37
# 1            0.022012           0.722222              26
# 2            0.015130           0.583333              21
# 3            0.052253           0.838710              26
# 4           -0.012747           0.307692               8

# %%
PFAM_ALL_results_df = pd.merge(PFAM_results_df, all_pfam_results_df, left_on="model", right_on="all_pfam")

# %%
PFAM_ALL_results_df.head()
# Out:
#      model   n  pfam_wilcoxon_W  pfam_p_value  pfam_median_delta_rho  \
# 0  PF06467   8             35.0      0.007812               0.127909
# 1  PF00013   9             45.0      0.001953               0.159571
# 2  PF00595  31            351.0      0.021727               0.014384
# 3  PF00249  15            117.0      0.000153               0.075475
# 4  PF00627   7             25.0      0.039062               0.059979
#
#    pfam_mean_delta_rho  pfam_frac_improved  pfam_n_improved all_pfam  all_n  \
# 0             0.154714            0.875000                7  PF06467      8
# 1             0.137493            1.000000                9  PF00013      9
# 2             0.031646            0.612903               19  PF00595     31
# 3             0.083639            0.866667               13  PF00249     15
# 4             0.084044            0.857143                6  PF00627      7
#
#    all_wilcoxon_W  all_p_value  all_median_delta_rho  all_mean_delta_rho  \
# 0            36.0     0.003906              0.079918            0.101562
# 1            40.0     0.019531              0.059516            0.069030
# 2           452.0     0.000007              0.040634            0.052253
# 3           113.0     0.000580              0.065086            0.055078
# 4            24.0     0.054688              0.090887            0.074314
#
#    all_frac_improved  all_n_improved
# 0           1.000000               8
# 1           0.777778               7
# 2           0.838710              26
# 3           0.800000              12
# 4           0.714286               5

# %%
PFAM_ALL_results_df = PFAM_ALL_results_df.rename(columns=
                                                 {
                                                     "model": "pfam"
                                                 })

# %%
PFAM_ALL_results_df.head()
# Out:
#       pfam   n  pfam_wilcoxon_W  pfam_p_value  pfam_median_delta_rho  \
# 0  PF06467   8             35.0      0.007812               0.127909
# 1  PF00013   9             45.0      0.001953               0.159571
# 2  PF00595  31            351.0      0.021727               0.014384
# 3  PF00249  15            117.0      0.000153               0.075475
# 4  PF00627   7             25.0      0.039062               0.059979
#
#    pfam_mean_delta_rho  pfam_frac_improved  pfam_n_improved all_pfam  all_n  \
# 0             0.154714            0.875000                7  PF06467      8
# 1             0.137493            1.000000                9  PF00013      9
# 2             0.031646            0.612903               19  PF00595     31
# 3             0.083639            0.866667               13  PF00249     15
# 4             0.084044            0.857143                6  PF00627      7
#
#    all_wilcoxon_W  all_p_value  all_median_delta_rho  all_mean_delta_rho  \
# 0            36.0     0.003906              0.079918            0.101562
# 1            40.0     0.019531              0.059516            0.069030
# 2           452.0     0.000007              0.040634            0.052253
# 3           113.0     0.000580              0.065086            0.055078
# 4            24.0     0.054688              0.090887            0.074314
#
#    all_frac_improved  all_n_improved
# 0           1.000000               8
# 1           0.777778               7
# 2           0.838710              26
# 3           0.800000              12
# 4           0.714286               5

# %%
a = PFAM_ALL_results_df['pfam_n_improved']
b = PFAM_ALL_results_df['all_n_improved']
diff = b - a

w_n_improved, p_n_improved = stats.wilcoxon(a, b)
print(len(a))
print(w_n_improved)
print(p_n_improved)

print(f"Median improvement {diff.median()}")
print(f"Mean improvement {diff.mean()}")
print((diff > 0).mean())
improved = PFAM_ALL_results_df[b > a]['pfam']
print(len(improved))

diff.hist(bins=30)
plt.show()
# Out:
# 28
# 128.5
# 0.5379460230086341
# Median improvement 0.0
# Mean improvement 1.7857142857142858
# 0.39285714285714285
# 11

# %% [markdown]
# # Domain trained models

# %%
df_doms = pd.read_csv("/Users/johnhutchens/Desktop/Practicum/Data/ESM2_ft_all_doms_sp.csv.gz")
# df_doms.to_csv("/Users/johnhutchens/Desktop/Practicum/Data/ESM2_ft_all_doms_sp.csv.gz", index=False, compression='gzip')

# %%
df_doms.head()
# Out:
#          model_domain       target_domain model_pfam target_pfam  same_pfam  \
# 0  A0PJY2_PF00096_289  A0PJY2_PF00096_289    PF00096     PF00096       True
# 1  A0PJY2_PF00096_289  A1X283_PF00018_155    PF00096     PF00018      False
# 2  A0PJY2_PF00096_289  A1X283_PF00018_222    PF00096     PF00018      False
# 3  A0PJY2_PF00096_289  A6NK59_PF07525_532    PF00096     PF07525      False
# 4  A0PJY2_PF00096_289  O00308_PF00397_440    PF00096     PF00397      False
#
#    is_self  ft_rho_test  ft_rho_full  baseline_rho_test  baseline_rho_full  \
# 0     True     0.304414     0.362050           0.247891           0.276918
# 1    False     0.488040     0.514951           0.498734           0.525018
# 2    False     0.435782     0.392745           0.453662           0.409388
# 3    False     0.139828     0.170460           0.135431           0.165628
# 4    False     0.712059     0.693012           0.711619           0.692651
#
#    delta_rho_test  delta_rho_full  delta_rho
# 0        0.056523        0.085132   0.056523
# 1       -0.010694       -0.010067  -0.010067
# 2       -0.017881       -0.016643  -0.016643
# 3        0.004397        0.004831   0.004831
# 4        0.000441        0.000361   0.000361

# %%
df_same = df_doms[df_doms["same_pfam"] == True]

# %%
agg = (
    df_same.groupby(["model_pfam", "model_domain"])
    .agg(
        median_ft_rho=("ft_rho_full", "median"),
        n=("ft_rho_full", "size")
    )
    .reset_index()
)

# %%
best_per_pfam = agg.loc[
    agg.groupby("model_pfam")["median_ft_rho"].idxmax()
].reset_index(drop=True)

# %%
best_per_pfam.head()
# Out:
#   model_pfam        model_domain  median_ft_rho   n
# 0    PF00010   Q05195_PF00010_58       0.413826   2
# 1    PF00013   Q96AE4_PF00013_98       0.677280   9
# 2    PF00018  A1X283_PF00018_222       0.644807  36
# 3    PF00030   P07315_PF00030_91       0.482858  12
# 4    PF00035   P78563_PF00035_80       0.668719   2

# %%
worst_per_pfam = agg.loc[
    agg.groupby("model_pfam")["median_ft_rho"].idxmin()
].reset_index(drop=True)

# %%
worst_per_pfam.head()
# Out:
#   model_pfam        model_domain  median_ft_rho   n
# 0    PF00010   P50539_PF00010_70       0.401445   2
# 1    PF00013  Q5U5Q3_PF00013_325       0.423959   9
# 2    PF00018  O15259_PF00018_152       0.542900  36
# 3    PF00030   P07320_PF00030_90       0.374005  12
# 4    PF00035  O95793_PF00035_183       0.633417   2

# %%
best_per_pfam_list = list(best_per_pfam['model_domain'])
worst_per_pfam_list = list(worst_per_pfam['model_domain'])

# %% [markdown]
# # Boxplots

# %%
df_best_worst = df_same[df_same['model_domain'].isin(best_per_pfam_list + worst_per_pfam_list)]

# %%
df_best_worst
# Out:
#                model_domain        target_domain model_pfam target_pfam  \
# 1031     A1X283_PF00018_222   A1X283_PF00018_155    PF00018     PF00018
# 1032     A1X283_PF00018_222   A1X283_PF00018_222    PF00018     PF00018
# 1049     A1X283_PF00018_222   O15259_PF00018_152    PF00018     PF00018
# 1059     A1X283_PF00018_222   O43295_PF00018_745    PF00018     PF00018
# 1063     A1X283_PF00018_222   O43586_PF00018_361    PF00018     PF00018
# ...                     ...                  ...        ...         ...
# 263677   Q9Y618_PF00249_613   Q9Y618_PF00249_613    PF00249     PF00249
# 264709  Q9Y6V0_PF05715_1058  Q9Y6V0_PF05715_1058    PF05715     PF05715
# 264751   P02640_PF02209_762   O75366_PF02209_785    PF02209     PF02209
# 264798   P02640_PF02209_762   P02640_PF02209_762    PF02209     PF02209
# 264816   P02640_PF02209_762   P09327_PF02209_793    PF02209     PF02209
#
#         same_pfam  is_self  ft_rho_test  ft_rho_full  baseline_rho_test  \
# 1031         True    False     0.539055     0.568788           0.498734
# 1032         True     True     0.598131     0.650087           0.453662
# 1049         True    False     0.411486     0.436424           0.290399
# 1059         True    False     0.658624     0.646759           0.605646
# 1063         True    False     0.659806     0.691469           0.616270
# ...           ...      ...          ...          ...                ...
# 263677       True     True     0.104205     0.135344           0.259509
# 264709       True     True     0.584861     0.566163           0.328462
# 264751       True    False     0.305803     0.363079           0.147516
# 264798       True     True     0.715922     0.734059           0.572988
# 264816       True    False     0.443309     0.445582           0.203171
#
#         baseline_rho_full  delta_rho_test  delta_rho_full  delta_rho
# 1031             0.525018        0.040321        0.043770   0.043770
# 1032             0.409388        0.144469        0.240700   0.144469
# 1049             0.294717        0.121087        0.141708   0.141708
# 1059             0.583822        0.052978        0.062937   0.062937
# 1063             0.612592        0.043536        0.078878   0.078878
# ...                   ...             ...             ...        ...
# 263677           0.265677       -0.155304       -0.130334  -0.155304
# 264709           0.284076        0.256399        0.282087   0.256399
# 264751           0.214390        0.158287        0.148689   0.148689
# 264798           0.563443        0.142934        0.170616   0.142934
# 264816           0.186976        0.240139        0.258606   0.258606
#
# [963 rows x 13 columns]

# %%
pfams = (
    df_best_worst["target_pfam"]
    .value_counts()
    .head(10)
    .index
)

fig, ax = plt.subplots(figsize=(16, 7))

positions = []
data = []
colors = []

group_centers = []
group_labels = []

x = 0

medianprops = dict(color='black', linewidth=1.5)

for pfam in pfams:

    sub = df_best_worst[df_best_worst["target_pfam"] == pfam]

    models = sub["model_domain"].unique()

    pfam_positions = []

    for i, model in enumerate(models):

        vals = sub.loc[
            sub["model_domain"] == model,
            "ft_rho_full"
        ].dropna()

        pos = x + i

        data.append(vals)
        positions.append(pos)
        pfam_positions.append(pos)

        colors.append(["orange", "orange"][i % 2])

    # center label between the two boxes
    group_centers.append(np.mean(pfam_positions))
    group_labels.append(pfam)

    x += 3  # gap between PFAM groups

# boxplots
bp = ax.boxplot(
    data,
    positions=positions,
    widths=0.7,
    patch_artist=True,
    showfliers=False,
    medianprops=medianprops
)

# colors
for patch, color in zip(bp["boxes"], colors):
    patch.set_facecolor(color)

# x-axis now labeled by PFAM
ax.set_xticks(group_centers)
ax.set_xticklabels(group_labels, rotation=45)

ax.set_ylabel("ft_rho_full")
ax.set_xlabel("PFAM")
ax.set_title("Two Models Compared Within Each PFAM")

# legend
ax.plot([], [], color="orange", linewidth=10, label="Model 1")
ax.plot([], [], color="orange", linewidth=10, label="Model 2")
ax.legend()

plt.tight_layout()
plt.show()

# %%
df_base = df_valid[df_valid['model'] == df_valid['pfam']]
df_ft_all = df_valid[df_valid['model'] == 'all_pfams']
df_ft_pfam = df_valid[df_valid['model'] == df_valid['pfam']]

# %% [markdown]
# # First 10 PFAMs by number of domains

# %%
# pfam_order = df_valid['pfam'].value_counts().head(10).index
pfam_order = pfam_counts['pfam'].head(10)

spacing = 1.6
x = np.arange(len(pfam_order))*spacing
width = 0.16

# colors
worst_model_color = "steelblue"
best_model_color = "orange"

base_color = 'lightgray'
ft_all_color = "#80b0f8"
ft_pfam_color = "#fa8376"

fig, ax = plt.subplots(figsize=(22, 7))

medianprops = dict(color='black', linewidth=1.5)

# ---------------------------------------------------
# Main model distributions
# ---------------------------------------------------

base_data = [
    df_base[df_base['pfam'] == p]['rho_base']
    for p in pfam_order
]

ft_all_data = [
    df_ft_all[df_ft_all['pfam'] == p]['rho_ft']
    for p in pfam_order
]

ft_pfam_data = [
    df_ft_pfam[df_ft_pfam['pfam'] == p]['rho_ft']
    for p in pfam_order
]

# ---------------------------------------------------
# PFAM-specific best/worst models
# ---------------------------------------------------

worst_model_data = []
best_model_data = []

for pfam in pfam_order:

    sub = df_best_worst[df_best_worst["target_pfam"] == pfam]

    # median performance per model
    model_medians = (
        sub.groupby("model_domain")["ft_rho_full"]
        .median()
        .sort_values()
    )

    worst_model = model_medians.index[0]
    best_model = model_medians.index[-1]

    worst_vals = sub.loc[
        sub["model_domain"] == worst_model,
        "ft_rho_full"
    ].dropna()

    best_vals = sub.loc[
        sub["model_domain"] == best_model,
        "ft_rho_full"
    ].dropna()

    worst_model_data.append(worst_vals)
    best_model_data.append(best_vals)

# ---------------------------------------------------
# Plot order:
# worst | base | ft_all | ft_pfam | best
# ---------------------------------------------------

ax.boxplot(
    worst_model_data,
    positions=x - 2 * width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=best_model_color),
    medianprops=medianprops
)

ax.boxplot(
    base_data,
    positions=x - width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=base_color),
    medianprops=medianprops
)

ax.boxplot(
    ft_all_data,
    positions=x,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=ft_all_color),
    medianprops=medianprops
)

ax.boxplot(
    ft_pfam_data,
    positions=x + width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=ft_pfam_color),
    medianprops=medianprops
)

ax.boxplot(
    best_model_data,
    positions=x + 2 * width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=best_model_color),
    medianprops=medianprops
)

# ---------------------------------------------------
# Labels
# ---------------------------------------------------

ax.set_xticks(x)
ax.set_xticklabels(pfam_order, rotation=90)

ax.set_xlabel("PFAM")
ax.set_ylabel("rho")
ax.set_title("Worst Model vs Base vs FT All vs FT PFAM vs Best Model")

# legend
legend_handles = [
    mpatches.Patch(color=best_model_color, label='Beset/Worst Dom model'),
    mpatches.Patch(color=base_color, label='Base'),
    mpatches.Patch(color=ft_all_color, label='FT all'),
    mpatches.Patch(color=ft_pfam_color, label='FT pfam'),
    # mpatches.Patch(color=worst_model_color, label='Best PFAM model')
]

ax.legend(handles=legend_handles)

plt.tight_layout()
plt.show()

# %%
pfam_counts[0:10]
# Out:
#       pfam  count
# 0  PF00046     37
# 1  PF00096     36
# 2  PF00018     36
# 3  PF00595     31
# 4  PF00397     26
# 5  PF00505     17
# 6  PF00249     15
# 7  PF02037     14
# 8  PF00157     12
# 9  PF01846     12

# %% [markdown]
# # 11-20 PFAMs by number of domains

# %%
pfam_counts['pfam'].iloc[10:20]
# Out:
# 10    PF00030
# 11    PF00628
# 12    PF00105
# 13    PF00641
# 14    PF00313
# 15    PF00643
# 16    PF00013
# 17    PF00642
# 18    PF00412
# 19    PF06467
# Name: pfam, dtype: object

# %%
# pfam_order = df_valid['pfam'].value_counts().index[10:20]
pfam_order = pfam_counts['pfam'].iloc[10:20]

spacing = 1.6
x = np.arange(len(pfam_order))*spacing
width = 0.16

# colors
worst_model_color = "steelblue"
best_model_color = "orange"

base_color = 'lightgray'
ft_all_color = "#80b0f8"
ft_pfam_color = "#fa8376"

fig, ax = plt.subplots(figsize=(22, 7))

medianprops = dict(color='black', linewidth=1.5)

# ---------------------------------------------------
# Main model distributions
# ---------------------------------------------------

base_data = [
    df_base[df_base['pfam'] == p]['rho_base']
    for p in pfam_order
]

ft_all_data = [
    df_ft_all[df_ft_all['pfam'] == p]['rho_ft']
    for p in pfam_order
]

ft_pfam_data = [
    df_ft_pfam[df_ft_pfam['pfam'] == p]['rho_ft']
    for p in pfam_order
]

# ---------------------------------------------------
# PFAM-specific best/worst models
# ---------------------------------------------------

worst_model_data = []
best_model_data = []

for pfam in pfam_order:

    sub = df_best_worst[df_best_worst["target_pfam"] == pfam]

    # median performance per model
    model_medians = (
        sub.groupby("model_domain")["ft_rho_full"]
        .median()
        .sort_values()
    )

    worst_model = model_medians.index[0]
    best_model = model_medians.index[-1]

    worst_vals = sub.loc[
        sub["model_domain"] == worst_model,
        "ft_rho_full"
    ].dropna()

    best_vals = sub.loc[
        sub["model_domain"] == best_model,
        "ft_rho_full"
    ].dropna()

    worst_model_data.append(worst_vals)
    best_model_data.append(best_vals)

# ---------------------------------------------------
# Plot order:
# worst | base | ft_all | ft_pfam | best
# ---------------------------------------------------

ax.boxplot(
    worst_model_data,
    positions=x - 2 * width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=best_model_color),
    medianprops=medianprops
)

ax.boxplot(
    base_data,
    positions=x - width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=base_color),
    medianprops=medianprops
)

ax.boxplot(
    ft_all_data,
    positions=x,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=ft_all_color),
    medianprops=medianprops
)

ax.boxplot(
    ft_pfam_data,
    positions=x + width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=ft_pfam_color),
    medianprops=medianprops
)

ax.boxplot(
    best_model_data,
    positions=x + 2 * width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=best_model_color),
    medianprops=medianprops
)

# ---------------------------------------------------
# Labels
# ---------------------------------------------------

ax.set_xticks(x)
ax.set_xticklabels(pfam_order, rotation=90)

ax.set_xlabel("PFAM")
ax.set_ylabel("rho")
ax.set_title("Worst Model vs Base vs FT All vs FT PFAM vs Best Model")

# legend
legend_handles = [
    mpatches.Patch(color=best_model_color, label='Beset/Worst Dom model'),
    mpatches.Patch(color=base_color, label='Base'),
    mpatches.Patch(color=ft_all_color, label='FT all'),
    mpatches.Patch(color=ft_pfam_color, label='FT pfam'),
    # mpatches.Patch(color=worst_model_color, label='Best PFAM model')
]

ax.legend(handles=legend_handles)

plt.tight_layout()
plt.show()

# %%
pfam_counts[10:20]
# Out:
#        pfam  count
# 10  PF00030     12
# 11  PF00628     11
# 12  PF00105     10
# 13  PF00641     10
# 14  PF00313      9
# 15  PF00643      9
# 16  PF00013      9
# 17  PF00642      8
# 18  PF00412      8
# 19  PF06467      8

# %%
pfam_counts['pfam'].iloc[20:30]
# Out:
# 20     PF02376
# 21     PF14604
# 22     PF00627
# 23     PF02198
# 24     PF00226
# 25     PF13499
# 26     PF00536
# 27     PF07647
# 28     PF02209
# 29    rockdoms
# Name: pfam, dtype: object

# %%
# pfam_order = df_valid['pfam'].value_counts().index[20:30]
pfam_order = pfam_counts['pfam'].iloc[20:28]

spacing = 1.6
x = np.arange(len(pfam_order))*spacing
width = 0.16

# colors
worst_model_color = "steelblue"
best_model_color = "orange"

base_color = 'lightgray'
ft_all_color = "#80b0f8"
ft_pfam_color = "#fa8376"

fig, ax = plt.subplots(figsize=(22, 7))
medianprops = dict(color='black', linewidth=1.5)

# ---------------------------------------------------
# Main model distributions
# ---------------------------------------------------

base_data = [
    df_base[df_base['pfam'] == p]['rho_base']
    for p in pfam_order
]

ft_all_data = [
    df_ft_all[df_ft_all['pfam'] == p]['rho_ft']
    for p in pfam_order
]

ft_pfam_data = [
    df_ft_pfam[df_ft_pfam['pfam'] == p]['rho_ft']
    for p in pfam_order
]

# ---------------------------------------------------
# PFAM-specific best/worst models
# ---------------------------------------------------

# worst_model_data = []
# best_model_data = []

# for pfam in pfam_order:
#     print(pfam)

#     sub = df_best_worst[df_best_worst["target_pfam"] == pfam]

#     # no entries for this PFAM
#     if sub.empty:
#         worst_model_data.append([np.nan])
#         best_model_data.append([np.nan])
#         continue

#     # median performance per model
#     model_medians = (
#         sub.groupby("model_domain")["ft_rho_full"]
#         .median()
#         .sort_values()
#     )

#     worst_model = model_medians.index[0]
#     best_model = model_medians.index[-1]

#     worst_vals = sub.loc[
#         sub["model_domain"] == worst_model,
#         "ft_rho_full"
#     ].dropna()

#     best_vals = sub.loc[
#         sub["model_domain"] == best_model,
#         "ft_rho_full"
#     ].dropna()

#     # if somehow empty after dropna
#     if len(worst_vals) == 0:
#         worst_vals = [np.nan]

#     if len(best_vals) == 0:
#         best_vals = [np.nan]

#     worst_model_data.append(worst_vals)
#     best_model_data.append(best_vals)

worst_model_data = []
best_model_data = []

for pfam in pfam_order:
    print(pfam)
    sub = df_best_worst[df_best_worst["target_pfam"] == pfam]

    # median performance per model
    model_medians = (
        sub.groupby("model_domain")["ft_rho_full"]
        .median()
        .sort_values()
    )

    worst_model = model_medians.index[0]
    best_model = model_medians.index[-1]

    worst_vals = sub.loc[
        sub["model_domain"] == worst_model,
        "ft_rho_full"
    ].dropna()

    best_vals = sub.loc[
        sub["model_domain"] == best_model,
        "ft_rho_full"
    ].dropna()

    worst_model_data.append(worst_vals)
    best_model_data.append(best_vals)

# ---------------------------------------------------
# Plot order:
# worst | base | ft_all | ft_pfam | best
# ---------------------------------------------------

ax.boxplot(
    worst_model_data,
    positions=x - 2 * width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=best_model_color),
    medianprops=medianprops
)

ax.boxplot(
    base_data,
    positions=x - width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=base_color),
    medianprops=medianprops
)

ax.boxplot(
    ft_all_data,
    positions=x,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=ft_all_color),
    medianprops=medianprops
)

ax.boxplot(
    ft_pfam_data,
    positions=x + width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=ft_pfam_color),
    medianprops=medianprops
)

ax.boxplot(
    best_model_data,
    positions=x + 2 * width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=best_model_color),
    medianprops=medianprops
)

# ---------------------------------------------------
# Labels
# ---------------------------------------------------

ax.set_xticks(x)
ax.set_xticklabels(pfam_order, rotation=90)

ax.set_xlabel("PFAM")
ax.set_ylabel("rho")
ax.set_title("Worst Model vs Base vs FT All vs FT PFAM vs Best Model")

# legend
legend_handles = [
    mpatches.Patch(color=best_model_color, label='Beset/Worst Dom model'),
    mpatches.Patch(color=base_color, label='Base'),
    mpatches.Patch(color=ft_all_color, label='FT all'),
    mpatches.Patch(color=ft_pfam_color, label='FT pfam'),
    # mpatches.Patch(color=worst_model_color, label='Best PFAM model')
]

ax.legend(handles=legend_handles)

plt.tight_layout()
plt.show()
# Out:
# PF02376
# PF14604
# PF00627
# PF02198
# PF00226
# PF13499
# PF00536
# PF07647

# %%
pfam_counts.head(30)
# Out:
#         pfam  count
# 0    PF00046     37
# 1    PF00096     36
# 2    PF00018     36
# 3    PF00595     31
# 4    PF00397     26
# 5    PF00505     17
# 6    PF00249     15
# 7    PF02037     14
# 8    PF00157     12
# 9    PF01846     12
# 10   PF00030     12
# 11   PF00628     11
# 12   PF00105     10
# 13   PF00641     10
# 14   PF00313      9
# 15   PF00643      9
# 16   PF00013      9
# 17   PF00642      8
# 18   PF00412      8
# 19   PF06467      8
# 20   PF02376      8
# 21   PF14604      8
# 22   PF00627      7
# 23   PF02198      6
# 24   PF00226      6
# 25   PF13499      6
# 26   PF00536      6
# 27   PF07647      5
# 28   PF02209      4
# 29  rockdoms      3

# %%
df_valid['pfam'].value_counts()
# Out:
# pfam
# PF00046    4699
# PF00018    4572
# PF00096    4572
# PF00595    3937
# PF00397    3302
# PF00505    2159
# PF00249    1905
# PF02037    1778
# PF00030    1524
# PF01846    1524
# PF00157    1524
# PF00628    1397
# PF00641    1270
# PF00105    1270
# PF00313    1143
# PF00643    1143
# PF00013    1143
# PF06467    1016
# PF00642    1016
# PF00412    1016
# PF02376    1016
# PF14604    1016
# PF00627     889
# PF13499     762
# PF02198     762
# PF00226     762
# PF00536     762
# PF07647     635
# Name: count, dtype: int64

# %%
# make a new dataframe with best domain only, worst domain only, pfam, and base for top 10 pfams by number of doms
pfam_order = df_valid['pfam'].value_counts().head(10).index

x = np.arange(len(pfam_order))

# widths
width = 0.18

# colors
base_color = 'lightgray'
ft_all_color = "#c0d8fd"
ft_pfam_color = "#fecdac"

model_colors = ["orange", "orange"]

fig, ax = plt.subplots(figsize=(20, 7))

medianprops = dict(color='black', linewidth=1.5)

# ---------------------------------------------------
# Main three boxplots
# ---------------------------------------------------

base_data = [
    df_base[df_base['pfam'] == p]['rho_base']
    for p in pfam_order
]

ft_all_data = [
    df_ft_all[df_ft_all['pfam'] == p]['rho_ft']
    for p in pfam_order
]

ft_pfam_data = [
    df_ft_pfam[df_ft_pfam['pfam'] == p]['rho_ft']
    for p in pfam_order
]

# base
ax.boxplot(
    base_data,
    positions=x - 1.5 * width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=base_color),
    medianprops=medianprops
)

# ft all
ax.boxplot(
    ft_all_data,
    positions=x - 0.5 * width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=ft_all_color),
    medianprops=medianprops
)

# ft pfam
ax.boxplot(
    ft_pfam_data,
    positions=x + 0.5 * width,
    widths=width,
    patch_artist=True,
    showfliers=False,
    boxprops=dict(facecolor=ft_pfam_color),
    medianprops=medianprops
)

# ---------------------------------------------------
# Add two PFAM-specific model boxplots
# ---------------------------------------------------

# ---------------------------------------------------
# Add two PFAM-specific model boxplots
# ordered by median ft_rho_full
# ---------------------------------------------------

model_data = []
model_positions = []
model_box_colors = []

for i, pfam in enumerate(pfam_order):

    sub = df_best_worst[df_best_worst["target_pfam"] == pfam]

    # compute median performance for each model
    model_medians = (
        sub.groupby("model_domain")["ft_rho_full"]
        .median()
        .sort_values()   # lowest first
    )

    ordered_models = model_medians.index.tolist()

    for j, model in enumerate(ordered_models):

        vals = sub.loc[
            sub["model_domain"] == model,
            "ft_rho_full"
        ].dropna()

        model_data.append(vals)

        # positions to right of original 3 boxes
        model_positions.append(i + 1.5 * width + j * width)

        # lower median = blue, higher median = orange
        model_box_colors.append(model_colors[j])

bp_models = ax.boxplot(
    model_data,
    positions=model_positions,
    widths=width,
    patch_artist=True,
    showfliers=False,
    medianprops=medianprops
)

for patch, color in zip(bp_models['boxes'], model_box_colors):
    patch.set_facecolor(color)

# model_data = []
# model_positions = []
# model_box_colors = []

# for i, pfam in enumerate(pfam_order):

#     sub = df_best_worst[df_best_worst["target_pfam"] == pfam]

#     models = sub["model_domain"].unique()[:2]

#     for j, model in enumerate(models):

#         vals = sub.loc[
#             sub["model_domain"] == model,
#             "ft_rho_full"
#         ].dropna()

#         model_data.append(vals)

#         # place to right of original 3 boxes
#         model_positions.append(i + 1.5 * width + j * width)

#         model_box_colors.append(model_colors[j])

# bp_models = ax.boxplot(
#     model_data,
#     positions=model_positions,
#     widths=width,
#     patch_artist=True,
#     showfliers=False,
#     medianprops=medianprops
# )

# for patch, color in zip(bp_models['boxes'], model_box_colors):
#     patch.set_facecolor(color)

# ---------------------------------------------------
# Labels
# ---------------------------------------------------

ax.set_xticks(x)
ax.set_xticklabels(pfam_order, rotation=90)

ax.set_xlabel("PFAM")
ax.set_ylabel("rho")
ax.set_title("Base vs FT Models vs Individual PFAM Models")

# legend
legend_handles = [
    mpatches.Patch(color=base_color, label='Base'),
    mpatches.Patch(color=ft_all_color, label='FT all'),
    mpatches.Patch(color=ft_pfam_color, label='FT pfam'),
    mpatches.Patch(color='orange', label='Best/Worst Domain Model'),
    # mpatches.Patch(color='orange', label='PFAM model 2')
]

ax.legend(handles=legend_handles)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Base vs all vs pfams

# %%
df_base = df_valid[df_valid['model'] == df_valid['pfam']]
df_ft_all = df_valid[df_valid['model'] == 'all_pfams']
df_ft_pfam = df_valid[df_valid['model'] == df_valid['pfam']]

# %%
pfam_order = df_valid['pfam'].value_counts().index

x = np.arange(len(pfam_order))
width = 0.25

base_color = 'lightgray'
ft_all_color = "#c0d8fd"
ft_pfam_color = "#fecdac"

base_data = [df_base[df_base['pfam'] == p]['rho_base'] for p in pfam_order]

ft_all_data = [
    df_ft_all[df_ft_all['pfam'] == p]['rho_ft'] for p in pfam_order
]

ft_pfam_data = [
    df_ft_pfam[df_ft_pfam['pfam'] == p]['rho_ft'] for p in pfam_order
]

fig, ax = plt.subplots(figsize=(18, 6))

medianprops = dict(color='black', linewidth=1.5)

# base
ax.boxplot(
    base_data,
    positions=x - width,
    widths=width,
    patch_artist=True,
    boxprops=dict(facecolor=base_color),
    medianprops=medianprops
)

# ft all
ax.boxplot(
    ft_all_data,
    positions=x,
    widths=width,
    patch_artist=True,
    boxprops=dict(facecolor=ft_all_color),
    medianprops=medianprops
)

# ft pfam
ax.boxplot(
    ft_pfam_data,
    positions=x + width,
    widths=width,
    patch_artist=True,
    boxprops=dict(facecolor=ft_pfam_color),
    medianprops=medianprops
)


ax.set_xticks(x)
ax.set_xticklabels(pfam_order, rotation=90)

ax.set_xlabel("PFAM")
ax.set_ylabel("rho")
ax.set_title("Base vs FT all vs FT pfam")

base_patch = mpatches.Patch(color=base_color, label='Base')
ft_all_patch = mpatches.Patch(color=ft_all_color, label='FT all')
ft_pfam_patch = mpatches.Patch(color=ft_pfam_color, label='FT pfam')

ax.legend(handles=[base_patch, ft_all_patch, ft_pfam_patch], title="Model")

plt.tight_layout()
plt.show()

# %%
df_all = df_valid[df_valid['model'] == 'all_pfams']

pfam_order = df_all['pfam'].value_counts().index

# numeric x positions
x = np.arange(len(pfam_order))
width = 0.35
medianprops = dict(color='black', linewidth=2)

fig, ax = plt.subplots(figsize=(20, 6))

# data aligned to pfam order
base_data = [df_all[df_all['pfam'] == p]['rho_base'] for p in pfam_order]
ft_data   = [df_all[df_all['pfam'] == p]['rho_ft'] for p in pfam_order]

# boxplots with offsets
ax.boxplot(base_data, 
           positions=x - width/2, 
           widths=width, 
           patch_artist=True,
           boxprops=dict(facecolor='beige'),
           medianprops=medianprops)

ax.boxplot(ft_data,
           positions=x + width/2, 
           widths=width, 
           patch_artist=True,
           boxprops=dict(facecolor='azure'),
           medianprops=medianprops)

# labels
ax.set_xticks(x)
ax.set_xticklabels(pfam_order, rotation=90)

ax.set_xlabel("PFAM")
ax.set_ylabel("rho")
ax.set_title("rho_base vs rho_ft across PFAMs")

base_patch = mpatches.Patch(color='beige', label='Base')
ft_patch   = mpatches.Patch(color='azure', label='FT all')

ax.legend(handles=[base_patch, ft_patch], title="Model")

plt.tight_layout()
plt.show()

# %%
df_plot = df_valid[df_valid['model'] == df_valid['pfam']]

pfam_order = df_plot['pfam'].value_counts().index

x = np.arange(len(pfam_order))
width = 0.35

fig, ax = plt.subplots(figsize=(16, 6))

# align data to pfam order
base_data = [df_plot[df_plot['pfam'] == p]['rho_base'] for p in pfam_order]
ft_data   = [df_plot[df_plot['pfam'] == p]['rho_ft'] for p in pfam_order]

medianprops = dict(color='black', linewidth=1.5)

# rho_base (left)
ax.boxplot(
    base_data,
    positions=x - width/2,
    widths=width,
    patch_artist=True,
    boxprops=dict(facecolor='#e6f5e6'),
    medianprops=medianprops
)

# rho_ft (right)
ax.boxplot(
    ft_data,
    positions=x + width/2,
    widths=width,
    patch_artist=True,
    boxprops=dict(facecolor="#e8e6ff"),
    medianprops=medianprops
)

# axis labels
ax.set_xticks(x)
ax.set_xticklabels(pfam_order, rotation=90)

ax.set_xlabel("PFAM")
ax.set_ylabel("rho")
ax.set_title("rho_base vs rho_ft (model == pfam)")

# legend
import matplotlib.patches as mpatches

base_patch = mpatches.Patch(color='#e6f5e6', label='rho_base')
ft_patch   = mpatches.Patch(color="#e8e6ff", label='rho_ft')

ax.legend(handles=[base_patch, ft_patch], title="Metric")

plt.tight_layout()
plt.show()

# %%
df_plot = df_valid[
    (df_valid['model'] == df_valid['pfam'])
]

# %%
pfam_order = df_plot['pfam'].value_counts().index

plt.figure(figsize=(14, 6))

sns.boxplot(
    data=df_plot,
    x='pfam',
    y='rho_ft',
    order=pfam_order,
    color='#dbe9ff'
)

plt.xticks(rotation=90)
plt.xlabel("PFAM")
plt.ylabel("rho_ft")
plt.title("rho_ft where model = pfam")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Make combined csv

# %%
# load pfam data
datafile = "/Users/johnhutchens/Desktop/Practicum/Data/ESM2_ESM2_ft_combined_sp_df.csv.gz"

with gzip.open(datafile, "rt") as f:
    df = pd.read_csv(f)

# %%
# load all domain data
datafile = "/Users/johnhutchens/Desktop/Practicum/Data/ESM2_ft_all_doms_run2_global_finetune_ESM2_ft_all_sp_df.csv.gz"

with gzip.open(datafile, "rt") as f:
    df_all = pd.read_csv(f)

# %%
df_all.head()
# Out:
#             domain_id uniprot_id     n  rho_base        p_base    rho_ft  \
# 0  Q9Y6N9_PF00595_207     Q9Y6N9  1255  0.378841  4.165029e-44  0.626113
# 1  P20936_PF00018_281     P20936  1158  0.422455  2.486852e-51  0.666934
# 2  Q86VP1_PF18112_729     Q86VP1   494  0.299746  1.029321e-11  0.531721
# 3  P22681_PF00627_854     P22681   850  0.235321  3.693812e-12  0.457588
# 4   Q9P0J7_PF05605_76     Q9P0J7  1093  0.303563  9.848891e-25  0.520061
#
#             p_ft  delta_rho     pfam
# 0  1.456364e-137   0.247273  PF00595
# 1  6.875281e-150   0.244478  PF00018
# 2   2.119634e-37   0.231975  PF18112
# 3   3.250431e-45   0.222268  PF00627
# 4   9.076428e-77   0.216498  PF05605

# %%
# counting domains in pfams

pfam_counts = (
    df_all['pfam']
    .value_counts()
    .reset_index()
)

pfam_counts.columns = ['pfam', 'count']

# %%
# list of pfams with at least 5 domains
pfam_g4 = pfam_counts[pfam_counts['count']>4]['pfam']

# %%
df_comb = pd.concat([df, df_all])

# %%
df_comb.head()
# Out:
#      model           domain_id uniprot_id in_pfam_train     n  rho_base  \
# 0  PF00010  Q7Z6G8_PF00536_812     Q7Z6G8         False  1143  0.257597
# 1  PF11722   Q9NUP7_PF11722_18     Q9NUP7          True   439  0.026799
# 2  PF00010  Q8WU90_PF18044_104     Q8WU90         False   397  0.166906
# 3  PF00569  Q9Y4J8_PF00569_235     Q9Y4J8          True  1119  0.188510
# 4  PF02209  P09327_PF02209_793     P09327          True   632  0.186976
#
#          p_base    rho_ft           p_ft  delta_rho     pfam
# 0  8.820103e-19  0.787307  6.918559e-242   0.529710  PF00536
# 1  5.754848e-01  0.539265   1.734913e-34   0.512467  PF11722
# 2  8.422100e-04  0.626052   1.362520e-44   0.459146  PF18044
# 3  2.071464e-10  0.629437  1.623944e-124   0.440927  PF00569
# 4  2.212267e-06  0.618647   5.136239e-68   0.431671  PF02209

# %%
df_comb['model'] = df_comb['model'].fillna('all_pfams')

# %%
df_comb.to_csv("/Users/johnhutchens/Desktop/Practicum/Data/ESM2_ft_all_pfam_sp.csv.gz", index=False, compression='gzip')

# %% [markdown]
# # Sanity checks

# %%
df_all[df_all['domain_id']=='Q9NUP7_PF11722_18']
# Out:
#              domain_id uniprot_id    n  rho_base    p_base    rho_ft  \
# 247  Q9NUP7_PF11722_18     Q9NUP7  439  0.026799  0.575485  0.064433
#
#          p_ft  delta_rho     pfam
# 247  0.177798   0.037634  PF11722

# %%
df[df['domain_id']=='Q9NUP7_PF11722_18']
# Out:
#          model          domain_id uniprot_id  in_pfam_train    n  rho_base  \
# 1      PF11722  Q9NUP7_PF11722_18     Q9NUP7           True  439  0.026799
# 27     PF02008  Q9NUP7_PF11722_18     Q9NUP7          False  439  0.026799
# 203    PF01246  Q9NUP7_PF11722_18     Q9NUP7          False  439  0.026799
# 241    PF18044  Q9NUP7_PF11722_18     Q9NUP7          False  439  0.026799
# 439    PF06220  Q9NUP7_PF11722_18     Q9NUP7          False  439  0.026799
# ...        ...                ...        ...            ...  ...       ...
# 59556  PF00787  Q9NUP7_PF11722_18     Q9NUP7          False  439  0.026799
# 60700  PF09329  Q9NUP7_PF11722_18     Q9NUP7          False  439  0.026799
# 60866  PF18366  Q9NUP7_PF11722_18     Q9NUP7          False  439  0.026799
# 61522  PF07525  Q9NUP7_PF11722_18     Q9NUP7          False  439  0.026799
# 63537  PF03638  Q9NUP7_PF11722_18     Q9NUP7          False  439  0.026799
#
#          p_base    rho_ft          p_ft  delta_rho     pfam
# 1      0.575485  0.539265  1.734913e-34   0.512467  PF11722
# 27     0.575485  0.348148  5.916150e-14   0.321349  PF11722
# 203    0.575485  0.242614  2.662307e-07   0.215815  PF11722
# 241    0.575485  0.233943  7.173038e-07   0.207144  PF11722
# 439    0.575485  0.201727  2.058449e-05   0.174928  PF11722
# ...         ...       ...           ...        ...      ...
# 59556  0.575485 -0.006317  8.950084e-01  -0.033115  PF11722
# 60700  0.575485 -0.022249  6.420053e-01  -0.049048  PF11722
# 60866  0.575485 -0.025644  5.920536e-01  -0.052443  PF11722
# 61522  0.575485 -0.044627  3.509041e-01  -0.071426  PF11722
# 63537  0.575485 -0.206531  1.288261e-05  -0.233330  PF11722
#
# [126 rows x 11 columns]

# %%
df['in_pfam_train'].unique()
# Out:
# array([False,  True])

# %%
df['model'].unique()
# Out:
# array(['PF00010', 'PF11722', 'PF00569', 'PF02209', 'PF02187', 'PF01246',
#        'PF06467', 'PF10650', 'PF02008', 'PF18044', 'PF01429', 'PF02295',
#        'PF00787', 'PF18112', 'PF09329', 'PF02207', 'PF00013', 'PF00412',
#        'PF00533', 'PF05225', 'PF00567', 'PF00536', 'PF05715', 'PF13639',
#        'PF02185', 'PF00096', 'PF00642', 'PF00240', 'PF00831', 'PF02037',
#        'PF00320', 'PF12171', 'PF00619', 'PF00595', 'PF00458', 'PF06220',
#        'PF11793', 'PF16557', 'PF00249', 'PF07647', 'PF00035', 'PF00280',
#        'PF05605', 'PF08313', 'PF02270', 'PF17035', 'PF00627', 'PF00538',
#        'PF01846', 'PF00778', 'PF01480', 'PF08073', 'PF02172', 'PF02376',
#        'PF07525', 'PF01335', 'PF02845', 'PF14369', 'PF00505', 'PF01381',
#        'PF13891', 'PF10264', 'PF00612', 'PF00130', 'PF03638', 'PF00046',
#        'PF04855', 'PF02359', 'PF11515', 'PF18410', 'PF18366', 'PF00643',
#        'PF02198', 'PF16558', 'PF02017', 'PF00385', 'PF02179', 'PF18694',
#        'PF02196', 'PF00789', 'PF04433', 'PF12678', 'PF03671', 'PF08711',
#        'PF00226', 'PF00779', 'PF00641', 'PF06839', 'PF01111', 'PF00030',
#        'PF07496', 'PF00646', 'PF07533', 'PF18016', 'PF00630', 'PF00157',
#        'PF02257', 'PF13499', 'PF01363', 'PF16577', 'PF04564', 'PF00628',
#        'PF12701', 'PF16866', 'PF12202', 'PF16366', 'PF00105', 'PF05207',
#        'PF00173', 'PF00564', 'PF05129', 'PF18346', 'PF02817', 'PF01023',
#        'PF01281', 'PF18387', 'PF07653', 'PF13341', 'PF09011', 'PF05741',
#        'PF14604', 'PF00018', 'PF00531', 'PF01485', 'PF00397', 'PF00313'],
#       dtype=object)
